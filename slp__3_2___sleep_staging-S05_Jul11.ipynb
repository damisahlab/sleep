# %% [markdown]
# ### Configuration

# %%
import os
import numpy as np
import pandas as pd

import mne
import yasa

import utils__config

# %%
os.chdir(utils__config.working_directory)
os.getcwd()
# Out:
# 'Z:\\Layton\\Sleep_083023'

# %% [markdown]
# ### Parameters

# %%
fif_path = 'Cache/Subject05/Jul11/S05_Jul11_256hz.fif'
hypno_path = 'Cache/Subject05/Jul11/S05_Jul11_hypnogram.csv'
potato_path = 'Cache/Subject05/Jul11/S05_Jul11_potatogram.csv'

# %%
sampling_freq = 256

# %% [markdown]
# ### Sleep Staging

# %% [markdown]
# Validated on scalp EEG with 85% accuracy against expert consensus: https://doi.org/10.7554/eLife.70092

# %%
raw = mne.io.read_raw_fif(fif_path, preload = True, verbose = False)

sls = yasa.SleepStaging(raw, 
                        eeg_name = 'C4', # required EEG channel, preferably central (C4 - M1)
                        eog_name = 'E2', #None, #'LOC', # optional EOG channel, preferably left LOC
                        emg_name = 'CHIN2' #None # optional EMG channel, preferably chin
                        )

hypnogram = sls.predict()

# Print the results of automated sleep staging
print(pd.DataFrame(hypnogram, columns = ['sleep_stage'])['sleep_stage'].value_counts())

# Recode string hypnogram to integer hypnogram
hypnogram = yasa.hypno_str_to_int(hypno = hypnogram)

# Calculate sleep statistics
sleep_stats = yasa.sleep_statistics(hypno = hypnogram, sf_hyp = (1/30))
print(sleep_stats)

# Upsample hypnogram (30s resolution) for compatibility
hypnogram = yasa.hypno_upsample_to_data(hypno = hypnogram,
                                        sf_hypno = (1/30),
                                        data = raw)

# Pick central electrode and plot
spectro_data = raw.copy().pick_channels(['C4']).get_data()[0]

fig = yasa.plot_spectrogram(data = spectro_data, 
                            sf = sampling_freq, 
                            hypno = hypnogram)
# Out:
# C:\Users\lal85\AppData\Local\Temp\3\ipykernel_31976\4212764847.py:1: RuntimeWarning: This filename (Cache/Subject05/Jul11/S05_Jul11_256hz.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fif_path, preload = True, verbose = False)
# 31-Oct-23 19:42:15 | INFO | Using pre-trained classifier: c:\Users\lal85\Miniconda3\envs\sandbox\lib\site-packages\yasa\classifiers\clf_eeg+eog+emg_lgb_0.5.0.joblib
# c:\Users\lal85\Miniconda3\envs\sandbox\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.24.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 31-Oct-23 19:42:15 | WARNING | Hypnogram is SHORTER than data by 20.00 seconds. Padding hypnogram with last value to match data.size.
# sleep_stage
# N2    554
# W     337
# R     207
# N1     53
# N3     10
# Name: count, dtype: int64
# {'TIB': 580.5, 'SPT': 569.0, 'WASO': 157.0, 'TST': 412.0, 'N1': 26.5, 'N2': 277.0, 'N3': 5.0, 'REM': 103.5, 'NREM': 308.5, 'SOL': 9.5, 'Lat_N1': 9.5, 'Lat_N2': 14.5, 'Lat_N3': 241.5, 'Lat_REM': 156.0, '%N1': 6.432038834951456, '%N2': 67.23300970873787, '%N3': 1.2135922330097086, '%REM': 25.12135922330097, '%NREM': 74.87864077669903, 'SE': 70.97329888027562, 'SME': 72.40773286467487}

# %%
# Export hypnogram
# (hypnograms need to be 1D numpy arrays, so save it this way)
np.savetxt(hypno_path, hypnogram, delimiter = ",")

# %% [markdown]
# ### Artifact Rejection (Riemann Potato)

# %%
boolean_artifacts, _ = yasa.art_detect(data = raw,
                                       sf = sampling_freq, 
                                       window = 5, # Window length of artifact evaluative epochs in seconds
                                       hypno = hypnogram, # this needs to be an upsampled hypnogram
                                       include = (1, 2, 3, 4), # Sleep stages to analyze
                                       method = 'covar', # Riemannian Potato algorithm
                                       threshold = 3, # Number of SD's for rejection
                                       verbose = 'info')

# Upsample artifact hypnogram (5s resolution) for compatibility
boolean_artifacts = yasa.hypno_upsample_to_data(hypno = boolean_artifacts,
                                                sf_hypno = (1/5),
                                                data = raw)

# Add -1 to hypnogram where artifacts were detected
processed_hypnogram = hypnogram.copy()
processed_hypnogram[boolean_artifacts] = -1

fig2 = yasa.plot_spectrogram(data = spectro_data, 
                             sf = sampling_freq, 
                             hypno = processed_hypnogram)
# Out:
# 09-Sep-23 23:39:30 | INFO | Number of unique values in hypno = 5
# 09-Sep-23 23:39:30 | INFO | Number of samples in data = 8921600
# 09-Sep-23 23:39:30 | INFO | Sampling frequency = 256.00 Hz
# 09-Sep-23 23:39:30 | INFO | Data duration = 34850.00 seconds
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LOF1 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LOF1 = 0.0149 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LOF10 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LOF10 = 0.0172 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPHC4 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPHC4 = 0.0221 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPHC8 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPHC8 = 0.0205 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPHC9 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPHC9 = 0.0204 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPC1 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPC1 = 0.0236 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LOF11 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LOF11 = 0.0170 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPC2 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPC2 = 0.0210 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPC3 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPC3 = 0.0217 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPC6 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPC6 = 0.0141 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPC8 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPC8 = 0.0143 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPC9 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPC9 = 0.0153 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPC10 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPC10 = 0.0154 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RSMA3 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RSMA3 = 0.0207 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RSMA4 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RSMA4 = 0.0130 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RSMA5 = 0.0001 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RSMA5 = 0.0135 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RSMA6 = 0.0001 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RSMA6 = 0.0182 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RSMA7 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RSMA7 = 0.0157 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of F3 = 4.9971 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of F3 = 18603.7594 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of C3 = 5.2167 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of C3 = 13174.8854 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of T3 = 3.0255 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of T3 = 8862.4742 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of O1 = 4.4257 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of O1 = 28307.5590 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of F4 = 3.4270 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of F4 = 9440.1245 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of C4 = 5.0595 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of C4 = 9922.3801 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of T4 = 4.4916 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of T4 = 10899.4427 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of O2 = 4.1114 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of O2 = 8872.8117 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of CZ = 4.1891 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of CZ = 11912.0446 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of ECG1 = 14.7541 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of ECG1 = 17050.3166 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of ECG2 = 17.4857 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of ECG2 = 16667.1276 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of E1 = 9.7002 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of E1 = 16954.7861 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of E2 = 8.5240 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of E2 = 16709.6639 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LAC7 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LAC7 = 0.0193 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LAC8 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LAC8 = 0.0200 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LAM1 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LAM1 = 0.0171 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LOF3 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LOF3 = 0.0127 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LAM2 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LAM2 = 0.0144 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LAM3 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LAM3 = 0.0144 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LAM4 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LAM4 = 0.0210 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LAM5 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LAM5 = 0.0173 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LAM6 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LAM6 = 0.0212 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LAM7 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LAM7 = 0.0191 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LHC1 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LHC1 = 0.0188 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LHC2 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LHC2 = 0.0186 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LHC5 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LHC5 = 0.0167 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LHC6 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LHC6 = 0.0151 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LHC7 = 0.0001 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LHC7 = 0.0212 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LHC8 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LHC8 = 0.0201 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of ROF1 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of ROF1 = 0.0204 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of ROF2 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of ROF2 = 0.0201 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of ROF5 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of ROF5 = 0.0155 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of ROF7 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of ROF7 = 0.0143 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of ROF8 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of ROF8 = 0.0100 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of ROF9 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of ROF9 = 0.0095 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAC3 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAC3 = 0.0217 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAC5 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAC5 = 0.0211 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAC6 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAC6 = 0.0209 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAC7 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAC7 = 0.0213 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LOF8 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LOF8 = 0.0107 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAM1 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAM1 = 0.0158 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAM2 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAM2 = 0.0162 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAM5 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAM5 = 0.0171 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAM6 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAM6 = 0.0159 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAM7 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAM7 = 0.0183 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RAM8 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RAM8 = 0.0184 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RHC1 = 0.0001 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RHC1 = 0.0205 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of LOF9 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of LOF9 = 0.0168 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RHC2 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RHC2 = 0.0182 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RHC5 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RHC5 = 0.0205 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RHC6 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RHC6 = 0.0177 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RHC7 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RHC7 = 0.0143 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RHC8 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RHC8 = 0.0265 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPHC1 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPHC1 = 0.0230 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPHC2 = 0.0002 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPHC2 = 0.0253 uV
# 09-Sep-23 23:39:38 | INFO | Trimmed standard deviation of RPHC3 = 0.0000 uV
# 09-Sep-23 23:39:38 | INFO | Peak-to-peak amplitude of RPHC3 = 0.0232 uV
# 09-Sep-23 23:39:44 | INFO | Number of channels in data = 74
# 09-Sep-23 23:39:44 | INFO | Number of samples in data = 8921600
# 09-Sep-23 23:39:44 | INFO | Sampling frequency = 256.00 Hz
# 09-Sep-23 23:39:44 | INFO | Data duration = 34850.00 seconds
# 09-Sep-23 23:39:44 | INFO | Number of epochs = 6970
# 09-Sep-23 23:39:44 | INFO | Artifact window = 5.00 seconds
# 09-Sep-23 23:39:44 | INFO | Method = covar
# 09-Sep-23 23:39:44 | INFO | Threshold = 3.00 standard deviations
# 09-Sep-23 23:40:00 | INFO | Stage 1: 8 / 450 epochs rejected (1.78%)
# 09-Sep-23 23:43:58 | INFO | Stage 2: 57 / 2808 epochs rejected (2.03%)
# 09-Sep-23 23:43:59 | INFO | Stage 3: 0 / 66 epochs rejected (0.00%)
# 09-Sep-23 23:45:20 | INFO | Stage 4: 49 / 1470 epochs rejected (3.33%)
# 09-Sep-23 23:45:20 | INFO | TOTAL: 114 / 6970 epochs rejected (1.64%)

# %%
# Export hypnogram with annotated artifacts
# (hypnograms need to be 1D numpy arrays, so save it this way)
np.savetxt(potato_path, processed_hypnogram, delimiter = ",")
