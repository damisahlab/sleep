# %% [markdown]
# ### Configuration

# %%
import os
import numpy as np
import pandas as pd

import mne
import yasa

import utils__config

# %%
os.chdir(utils__config.working_directory)
os.getcwd()
# Out:
# 'Z:\\Layton\\Sleep_083023'

# %% [markdown]
# ### Parameters

# %%
fif_path = 'Cache/Subject05/Jul12/S05_Jul12_256hz.fif'
hypno_path = 'Cache/Subject05/Jul12/S05_Jul12_hypnogram.csv'
potato_path = 'Cache/Subject05/Jul12/S05_Jul12_potatogram.csv'

# %%
sampling_freq = 256

# %% [markdown]
# ### Sleep Staging

# %% [markdown]
# Validated on scalp EEG with 85% accuracy against expert consensus: https://doi.org/10.7554/eLife.70092

# %%
raw = mne.io.read_raw_fif(fif_path, preload = True, verbose = False)

sls = yasa.SleepStaging(raw, 
                        eeg_name = 'C4', # required EEG channel, preferably central (C4 - M1)
                        eog_name = 'E2', #None, #'LOC', # optional EOG channel, preferably left LOC
                        emg_name = 'CHIN2' #None # optional EMG channel, preferably chin
                        )

hypnogram = sls.predict()

# Print the results of automated sleep staging
print(pd.DataFrame(hypnogram, columns = ['sleep_stage'])['sleep_stage'].value_counts())

# Recode string hypnogram to integer hypnogram
hypnogram = yasa.hypno_str_to_int(hypno = hypnogram)

# Calculate sleep statistics
sleep_stats = yasa.sleep_statistics(hypno = hypnogram, sf_hyp = (1/30))
print(sleep_stats)

# Upsample hypnogram (30s resolution) for compatibility
hypnogram = yasa.hypno_upsample_to_data(hypno = hypnogram,
                                        sf_hypno = (1/30),
                                        data = raw)

# Pick central electrode and plot
spectro_data = raw.copy().pick_channels(['C4']).get_data()[0]

fig = yasa.plot_spectrogram(data = spectro_data, 
                            sf = sampling_freq, 
                            hypno = hypnogram)
# Out:
# C:\Users\lal85\AppData\Local\Temp\3\ipykernel_8560\4212764847.py:1: RuntimeWarning: This filename (Cache/Subject05/Jul12/S05_Jul12_256hz.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw = mne.io.read_raw_fif(fif_path, preload = True, verbose = False)
# 31-Oct-23 19:43:27 | INFO | Using pre-trained classifier: c:\Users\lal85\Miniconda3\envs\sandbox\lib\site-packages\yasa\classifiers\clf_eeg+eog+emg_lgb_0.5.0.joblib
# c:\Users\lal85\Miniconda3\envs\sandbox\lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.24.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 31-Oct-23 19:43:27 | WARNING | Hypnogram is SHORTER than data by 20.00 seconds. Padding hypnogram with last value to match data.size.
# sleep_stage
# N2    721
# W     249
# R     223
# N1     65
# N3      7
# Name: count, dtype: int64
# {'TIB': 632.5, 'SPT': 616.0, 'WASO': 108.0, 'TST': 508.0, 'N1': 32.5, 'N2': 360.5, 'N3': 3.5, 'REM': 111.5, 'NREM': 396.5, 'SOL': 10.5, 'Lat_N1': 10.5, 'Lat_N2': 32.5, 'Lat_N3': 75.0, 'Lat_REM': 117.0, '%N1': 6.397637795275591, '%N2': 70.96456692913385, '%N3': 0.6889763779527559, '%REM': 21.948818897637796, '%NREM': 78.05118110236221, 'SE': 80.31620553359684, 'SME': 82.46753246753246}

# %%
# Export hypnogram
# (hypnograms need to be 1D numpy arrays, so save it this way)
np.savetxt(hypno_path, hypnogram, delimiter = ",")

# %% [markdown]
# ### Artifact Rejection (Riemann Potato)

# %%
boolean_artifacts, _ = yasa.art_detect(data = raw,
                                       sf = sampling_freq, 
                                       window = 5, # Window length of artifact evaluative epochs in seconds
                                       hypno = hypnogram, # this needs to be an upsampled hypnogram
                                       include = (1, 2, 3, 4), # Sleep stages to analyze
                                       method = 'covar', # Riemannian Potato algorithm
                                       threshold = 3, # Number of SD's for rejection
                                       verbose = 'info')

# Upsample artifact hypnogram (5s resolution) for compatibility
boolean_artifacts = yasa.hypno_upsample_to_data(hypno = boolean_artifacts,
                                                sf_hypno = (1/5),
                                                data = raw)

# Add -1 to hypnogram where artifacts were detected
processed_hypnogram = hypnogram.copy()
processed_hypnogram[boolean_artifacts] = -1

fig2 = yasa.plot_spectrogram(data = spectro_data, 
                             sf = sampling_freq, 
                             hypno = processed_hypnogram)
# Out:
# 09-Sep-23 23:39:34 | INFO | Number of unique values in hypno = 5
# 09-Sep-23 23:39:34 | INFO | Number of samples in data = 9720320
# 09-Sep-23 23:39:34 | INFO | Sampling frequency = 256.00 Hz
# 09-Sep-23 23:39:34 | INFO | Data duration = 37970.00 seconds
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LOF1 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LOF1 = 0.0020 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LOF10 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LOF10 = 0.0007 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPHC4 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPHC4 = 0.0168 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPHC8 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPHC8 = 0.0011 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPHC9 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPHC9 = 0.0007 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPC1 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPC1 = 0.0165 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LOF11 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LOF11 = 0.0009 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPC2 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPC2 = 0.0019 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPC3 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPC3 = 0.0007 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPC6 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPC6 = 0.0011 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPC8 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPC8 = 0.0009 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPC9 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPC9 = 0.0006 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPC10 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPC10 = 0.0009 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RSMA3 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RSMA3 = 0.0012 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RSMA4 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RSMA4 = 0.0010 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RSMA5 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RSMA5 = 0.0017 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RSMA6 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RSMA6 = 0.0018 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RSMA7 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RSMA7 = 0.0008 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of F3 = 4.8770 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of F3 = 722.7149 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of C3 = 5.0935 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of C3 = 670.2271 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of T3 = 2.8770 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of T3 = 531.0288 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of O1 = 3.9036 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of O1 = 1416.0266 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of F4 = 3.3561 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of F4 = 1164.9394 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of C4 = 4.6354 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of C4 = 506.7718 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of T4 = 4.3816 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of T4 = 688.9746 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of O2 = 3.7781 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of O2 = 420.1480 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of CZ = 3.5100 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of CZ = 1273.0543 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of ECG1 = 15.1553 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of ECG1 = 5613.5082 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of ECG2 = 18.2310 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of ECG2 = 5865.4000 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of E1 = 9.9307 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of E1 = 5608.7901 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of E2 = 8.0212 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of E2 = 5554.7652 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LAC7 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LAC7 = 0.0011 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LAC8 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LAC8 = 0.0010 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LAM1 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LAM1 = 0.0019 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LOF3 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LOF3 = 0.0014 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LAM2 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LAM2 = 0.0015 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LAM3 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LAM3 = 0.0052 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LAM4 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LAM4 = 0.0007 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LAM5 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LAM5 = 0.0011 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LAM6 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LAM6 = 0.0013 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LAM7 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LAM7 = 0.0009 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LHC1 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LHC1 = 0.0045 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LHC2 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LHC2 = 0.0032 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LHC5 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LHC5 = 0.0010 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LHC6 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LHC6 = 0.0016 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LHC7 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LHC7 = 0.0025 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LHC8 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LHC8 = 0.0014 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of ROF1 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of ROF1 = 0.0015 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of ROF2 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of ROF2 = 0.0014 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of ROF5 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of ROF5 = 0.0008 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of ROF7 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of ROF7 = 0.0016 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of ROF8 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of ROF8 = 0.0013 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of ROF9 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of ROF9 = 0.0013 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAC3 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAC3 = 0.0136 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAC5 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAC5 = 0.0009 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAC6 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAC6 = 0.0015 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAC7 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAC7 = 0.0009 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LOF8 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LOF8 = 0.0012 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAM1 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAM1 = 0.0018 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAM2 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAM2 = 0.0015 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAM5 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAM5 = 0.0020 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAM6 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAM6 = 0.0021 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAM7 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAM7 = 0.0014 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RAM8 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RAM8 = 0.0023 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RHC1 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RHC1 = 0.0047 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of LOF9 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of LOF9 = 0.0009 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RHC2 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RHC2 = 0.0023 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RHC5 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RHC5 = 0.0019 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RHC6 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RHC6 = 0.0020 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RHC7 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RHC7 = 0.0012 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RHC8 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RHC8 = 0.0013 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPHC1 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPHC1 = 0.0167 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPHC2 = 0.0001 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPHC2 = 0.0195 uV
# 09-Sep-23 23:39:44 | INFO | Trimmed standard deviation of RPHC3 = 0.0000 uV
# 09-Sep-23 23:39:44 | INFO | Peak-to-peak amplitude of RPHC3 = 0.0162 uV
# 09-Sep-23 23:39:50 | INFO | Number of channels in data = 74
# 09-Sep-23 23:39:50 | INFO | Number of samples in data = 9720320
# 09-Sep-23 23:39:50 | INFO | Sampling frequency = 256.00 Hz
# 09-Sep-23 23:39:50 | INFO | Data duration = 37970.00 seconds
# 09-Sep-23 23:39:50 | INFO | Number of epochs = 7594
# 09-Sep-23 23:39:50 | INFO | Artifact window = 5.00 seconds
# 09-Sep-23 23:39:50 | INFO | Method = covar
# 09-Sep-23 23:39:50 | INFO | Threshold = 3.00 standard deviations
# 09-Sep-23 23:40:05 | INFO | Stage 1: 10 / 378 epochs rejected (2.65%)
# 09-Sep-23 23:45:14 | INFO | Stage 2: 104 / 3642 epochs rejected (2.86%)
# 09-Sep-23 23:45:16 | INFO | Stage 3: 0 / 180 epochs rejected (0.00%)
# 09-Sep-23 23:46:53 | INFO | Stage 4: 64 / 1536 epochs rejected (4.17%)
# 09-Sep-23 23:46:53 | INFO | TOTAL: 178 / 7594 epochs rejected (2.34%)

# %%
# Export hypnogram with annotated artifacts
# (hypnograms need to be 1D numpy arrays, so save it this way)
np.savetxt(potato_path, processed_hypnogram, delimiter = ",")
